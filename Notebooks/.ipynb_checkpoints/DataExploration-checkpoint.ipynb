# %%
import pandas as pd
import regex as re
from statistics import mode

colnames=['Id_user','Name','Usage','TimePlayed','useless'] 

df_steam = pd.read_csv("../Datasets/steam-200k_officiel.csv", names=colnames)
df_vgsales = pd.read_csv("../Datasets/vgsales_officiel.csv")
df_steam_full = pd.read_csv("../Datasets/steam_games_complete.csv")

# %%
df_vgsales.head(5)
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
df_steam.drop(['useless'], axis=1, inplace=True)
df_steam.head()
len(df_steam)
# Out:
# 200000

# %%
df_steam_full.drop(["desc_snippet"],axis=1,inplace=True)
df_steam_full.drop(["recent_reviews"],axis=1,inplace=True)
df_steam_full.drop(["release_date"],axis=1,inplace=True)
df_steam_full.drop(["publisher"],axis=1,inplace=True)
df_steam_full.drop(["languages"],axis=1,inplace=True)
df_steam_full.drop(["achievements"],axis=1,inplace=True)
df_steam_full.drop(["minimum_requirements"],axis=1,inplace=True)
df_steam_full.drop(["recommended_requirements"],axis=1,inplace=True)
df_steam_full.drop(["original_price"],axis=1,inplace=True)
df_steam_full.drop(["discount_price"],axis=1,inplace=True)
df_steam_full.drop(["url"],axis=1,inplace=True)
df_steam_full.drop(["types"],axis=1,inplace=True)

# %%
df_steam_full.head()
# Out:
#                             name  \
# 0                           DOOM
# 1  PLAYERUNKNOWN'S BATTLEGROUNDS
# 2                     BATTLETECH
# 3                           DayZ
# 4                     EVE Online
#
#                                          all_reviews            developer  \
# 0  Very Positive,(42,550),- 92% of the 42,550 use...          id Software
# 1  Mixed,(836,608),- 49% of the 836,608 user revi...     PUBG Corporation
# 2  Mostly Positive,(7,030),- 71% of the 7,030 use...  Harebrained Schemes
# 3  Mixed,(167,115),- 61% of the 167,115 user revi...  Bohemia Interactive
# 4  Mostly Positive,(11,481),- 74% of the 11,481 u...                  CCP
#
#                                         popular_tags  \
# 0  FPS,Gore,Action,Demons,Shooter,First-Person,Gr...
# 1  Survival,Shooter,Multiplayer,Battle Royale,PvP...
# 2  Mechs,Strategy,Turn-Based,Turn-Based Tactics,S...
# 3  Survival,Zombies,Open World,Multiplayer,PvP,Ma...
# 4  Space,Massively Multiplayer,Sci-fi,Sandbox,MMO...
#
#                                         game_details  \
# 0  Single-player,Multi-player,Co-op,Steam Achieve...
# 1             Multi-player,Online Multi-Player,Stats
# 2  Single-player,Multi-player,Online Multi-Player...
# 3  Multi-player,Online Multi-Player,Steam Worksho...
# 4  Multi-player,Online Multi-Player,MMO,Co-op,Onl...
#
#                                                genre  \
# 0                                             Action
# 1             Action,Adventure,Massively Multiplayer
# 2                          Action,Adventure,Strategy
# 3             Action,Adventure,Massively Multiplayer
# 4  Action,Free to Play,Massively Multiplayer,RPG,...
#
#                                     game_description  \
# 0   About This Game Developed by id software, the...
# 1   About This Game  PLAYERUNKNOWN'S BATTLEGROUND...
# 2   About This Game  From original BATTLETECH/Mec...
# 3   About This Game The post-soviet country of Ch...
# 4                                  About This Game
#
#                                       mature_content
# 0                                                NaN
# 1   Mature Content Description  The developers de...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
df_steam['Name'].head(20)
# Out:
# 0     The Elder Scrolls V Skyrim
# 1     The Elder Scrolls V Skyrim
# 2                      Fallout 4
# 3                      Fallout 4
# 4                          Spore
# 5                          Spore
# 6              Fallout New Vegas
# 7              Fallout New Vegas
# 8                  Left 4 Dead 2
# 9                  Left 4 Dead 2
# 10                      HuniePop
# 11                      HuniePop
# 12                 Path of Exile
# 13                 Path of Exile
# 14                   Poly Bridge
# 15                   Poly Bridge
# 16                   Left 4 Dead
# 17                   Left 4 Dead
# 18               Team Fortress 2
# 19               Team Fortress 2
# Name: Name, dtype: object

# %%
def remove_spaces_specials_and_lower(expression):
    expression = str(expression)
    expression = expression.lower()
    expression = expression.strip()
    expression = re.sub('[^A-Za-z0-9]+', '', expression)
    return expression

# %%
df_steam["Name"].head()
# Out:
# 0    The Elder Scrolls V Skyrim
# 1    The Elder Scrolls V Skyrim
# 2                     Fallout 4
# 3                     Fallout 4
# 4                         Spore
# Name: Name, dtype: object

# %%
df_steam['NameClean'] = df_steam['Name'].apply(remove_spaces_specials_and_lower)
df_steam_full['nameClean'] = df_steam_full['name'].apply(remove_spaces_specials_and_lower)
df_steam_full["nameClean"][404] = "theelderscrollsvskyrim"
df_steam['NameClean'].head()
# Out:
# 0    theelderscrollsvskyrim
# 1    theelderscrollsvskyrim
# 2                  fallout4
# 3                  fallout4
# 4                     spore
# Name: NameClean, dtype: object

# %%
df_steam_full["nameClean"].head()
# Out:
# 0                           doom
# 1    playerunknownsbattlegrounds
# 2                     battletech
# 3                           dayz
# 4                      eveonline
# Name: nameClean, dtype: object

# %%
df_steam_full.drop(["name"],axis=1, inplace = True)

# df_steam.rename(columns={"NameClean":"Name"})
df_steam_full = df_steam_full.rename(columns={"nameClean":"NameClean"})
df_steam_full.drop_duplicates(subset="NameClean",keep = 'first', inplace=True)

# %%
#df_steam = df_steam[df_steam.BehaviorName != 'purchase']
df_steam.head()
# Out:
#      Id_user                        Name     Usage  TimePlayed  \
# 0  151603712  The Elder Scrolls V Skyrim  purchase         1.0
# 1  151603712  The Elder Scrolls V Skyrim      play       273.0
# 2  151603712                   Fallout 4  purchase         1.0
# 3  151603712                   Fallout 4      play        87.0
# 4  151603712                       Spore  purchase         1.0
#
#                 NameClean
# 0  theelderscrollsvskyrim
# 1  theelderscrollsvskyrim
# 2                fallout4
# 3                fallout4
# 4                   spore

# %%
df = pd.merge(df_steam, df_steam_full, left_on = "NameClean", right_on = "NameClean", indicator=True, how='left')

# %%
a=len(df_steam["NameClean"].unique())
b=len(df["NameClean"].unique())
c=len(df_steam_full["NameClean"].unique())
print("steam | merged | full\n",a,b,c)
# Out:
# steam | merged | full
#  5151 5151 40451

# %%
a=len(df_steam)
b=len(df)
c=len(df_steam_full)
print("steam | merged | full\n",a,b,c)
# Out:
# steam | merged | full
#  200000 200000 40451

# %%
df_leftonly = df.loc[df["_merge"] == "left_only"]
df_leftonly["NameClean"].value_counts()
# Out:
# halflife2lostcoast                         1158
# counterstrikeconditionzero                  904
# counterstrikeconditionzerodeletedscenes     773
# nomoreroominhell                            668
# callofdutymodernwarfare2multiplayer         634
#                                            ...
# coronamotorsport                              1
# castofthesevengodsendssoundtrack              1
# bumbledore                                    1
# moonrisebasegamewardenspack                   1
# legoindianajones2                             1
# Name: NameClean, Length: 2130, dtype: int64

# %%
df_steam_full[df_steam_full["NameClean"].str.contains("skyrim")]
# Out:
#                                              all_reviews  \
# 337    Very Positive,(2,137),- 80% of the 2,137 user ...
# 404    Very Positive,(14,443),- 83% of the 14,443 use...
# 6448   Overwhelmingly Positive,(932),- 98% of the 932...
# 39430                                                NaN
#
#                    developer  \
# 337    Bethesda Game Studios
# 404    Bethesda Game Studios
# 6448           The SKSE Team
# 39430  Bethesda Game Studios
#
#                                             popular_tags  \
# 337    RPG,Open World,VR,Singleplayer,Adventure,Fanta...
# 404    Open World,RPG,Adventure,Singleplayer,Fantasy,...
# 6448     Mod,Utilities,RPG,Game Development,Singleplayer
# 39430  Psychological Horror,Horror,Dark Humor,Memes,D...
#
#                                             game_details genre  \
# 337    Single-player,Steam Achievements,Full controll...   RPG
# 404    Single-player,Steam Achievements,Partial Contr...   RPG
# 6448            Single-player,Partial Controller Support   RPG
# 39430  Single-player,Downloadable Content,Steam Achie...   RPG
#
#                                         game_description  \
# 337     About This Game A true, full-length open-worl...
# 404     About This Game Winner of more than 200 Game ...
# 6448    About This Game The Skyrim Script Extender (S...
# 39430   About This Content Get Credits to be used in ...
#
#                                           mature_content  \
# 337                                                  NaN
# 404     Mature Content Description  The developers de...
# 6448                                                 NaN
# 39430   Mature Content Description  The developers de...
#
#                                               NameClean
# 337                            theelderscrollsvskyrimvr
# 404                              theelderscrollsvskyrim
# 6448                           skyrimscriptextenderskse
# 39430  theelderscrollsvskyrimspecialeditioncreationclub

# %%
df.head()
# Out:
#      Id_user                        Name     Usage  TimePlayed  \
# 0  151603712  The Elder Scrolls V Skyrim  purchase         1.0
# 1  151603712  The Elder Scrolls V Skyrim      play       273.0
# 2  151603712                   Fallout 4  purchase         1.0
# 3  151603712                   Fallout 4      play        87.0
# 4  151603712                       Spore  purchase         1.0
#
#                 NameClean                                        all_reviews  \
# 0  theelderscrollsvskyrim  Very Positive,(14,443),- 83% of the 14,443 use...
# 1  theelderscrollsvskyrim  Very Positive,(14,443),- 83% of the 14,443 use...
# 2                fallout4  Mostly Positive,(90,387),- 70% of the 90,387 u...
# 3                fallout4  Mostly Positive,(90,387),- 70% of the 90,387 u...
# 4                   spore  Very Positive,(15,680),- 87% of the 15,680 use...
#
#                developer                                       popular_tags  \
# 0  Bethesda Game Studios  Open World,RPG,Adventure,Singleplayer,Fantasy,...
# 1  Bethesda Game Studios  Open World,RPG,Adventure,Singleplayer,Fantasy,...
# 2  Bethesda Game Studios  Open World,Post-apocalyptic,Exploration,Single...
# 3  Bethesda Game Studios  Open World,Post-apocalyptic,Exploration,Single...
# 4                 Maxis™  Simulation,Sandbox,Open World,Exploration,Spac...
#
#                                         game_details       genre  \
# 0  Single-player,Steam Achievements,Partial Contr...         RPG
# 1  Single-player,Steam Achievements,Partial Contr...         RPG
# 2  Single-player,Steam Achievements,Full controll...         RPG
# 3  Single-player,Steam Achievements,Full controll...         RPG
# 4                                      Single-player  Simulation
#
#                                     game_description  \
# 0   About This Game Winner of more than 200 Game ...
# 1   About This Game Winner of more than 200 Game ...
# 2   About This Game Bethesda Game Studios, the aw...
# 3   About This Game Bethesda Game Studios, the aw...
# 4   About This Game  From Single Cell to Galactic...
#
#                                       mature_content _merge
# 0   Mature Content Description  The developers de...   both
# 1   Mature Content Description  The developers de...   both
# 2                                                NaN   both
# 3                                                NaN   both
# 4                                                NaN   both

# %%
a = "Hello, tamere, mange"
a.split(sep=",")[0]
df["all_reviews"].apply(lambda x:str(x).split(sep=",")[0]).value_counts()
# df["all_reviews"]
# Out:
# Very Positive              81829
# nan                        56518
# Overwhelmingly Positive    24543
# Mostly Positive            20273
# Mixed                      13896
# Positive                    1050
# Mostly Negative              734
# 1 user reviews               507
# 7 user reviews               182
# 8 user reviews                93
# 5 user reviews                89
# Very Negative                 60
# 4 user reviews                50
# Negative                      45
# 3 user reviews                39
# 2 user reviews                38
# 6 user reviews                25
# Overwhelmingly Negative       19
# 9 user reviews                10
# Name: all_reviews, dtype: int64

# %% [markdown]
# - Overwhelmingly Positive : 10
# - Very Positive : 9
# - Positive : 8
# - Mostly Positive : 7
# - Mixed : 6
# - nan : nan
# - Mostly Negative : 4
# - Negative : 3
# - Very Negative : 2
# - Overwhelmingly Negative : 1

# %%
df["genre"] = df["genre"].apply(lambda x:str(x).split(sep=",")[0]).replace("nan","other")

df2 = df.groupby("Id_user").agg({
    'NameClean' : lambda x: [','.join(x)],#if(x["Usage"]=="Purchase") else x,
    'genre' : lambda x: [','.join(x)]})


df2["nb_games_played"] = df["NameClean"].apply(lambda x : len(x))
df2.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/envs/MJ2MachineLearning/lib/python3.9/site-packages/pandas/core/indexes/base.py:3629, in Index.get_loc(self, key, method, tolerance)
#    3628 try:
# -> 3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
#
# File ~/opt/anaconda3/envs/MJ2MachineLearning/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/opt/anaconda3/envs/MJ2MachineLearning/lib/python3.9/site-packages/pandas/_libs/index.pyx:144, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index_class_helper.pxi:41, in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'Usage'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/envs/MJ2MachineLearning/lib/python3.9/site-packages/pandas/core/groupby/generic.py:287, in SeriesGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     286 try:
# --> 287     return self._python_agg_general(func, *args, **kwargs)
#     288 except KeyError:
#     289     # TODO: KeyError is raised in _python_agg_general,
#     290     #  see test_groupby.test_basic
#
# File ~/opt/anaconda3/envs/MJ2MachineLearning/lib/python3.9/site-packages/pandas/core/groupby/groupby.py:1490, in GroupBy._python_agg_general(self, func, *args, **kwargs)
#    1488 try:
#    1489     # if this function is invalid for this dtype, we will ignore it.
# -> 1490     result = self.grouper.agg_series(obj, f)
#    1491 except TypeError:
#
# File ~/opt/anaconda3/envs/MJ2MachineLearning/lib/python3.9/site-packages/pandas/core/groupby/ops.py:981, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     980 else:
# --> 981     result = self._aggregate_series_pure_python(obj, func)
#     983 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File ~/opt/anaconda3/envs/MJ2MachineLearning/lib/python3.9/site-packages/pandas/core/groupby/ops.py:1005, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#    1004 group = group.__finalize__(obj, method="groupby")
# -> 1005 res = func(group)
#    1006 res = libreduction.extract_result(res)
#
# File ~/opt/anaconda3/envs/MJ2MachineLearning/lib/python3.9/site-packages/pandas/core/groupby/groupby.py:1476, in GroupBy._python_agg_general.<locals>.<lambda>(x)
#    1475 func = com.is_builtin_func(func)
# -> 1476 f = lambda x: func(x, *args, **kwargs)
#    1478 # iterate through "columns" ex exclusions to populate output dict
#
# Input In [71], in <lambda>(x)
#       1 df["genre"] = df["genre"].apply(lambda x:str(x).split(sep=",")[0]).replace("nan","other")
#       3 df2 = df.groupby("Id_user").agg({
# ----> 4     'NameClean' : lambda x: [','.join(x)]if(x["Usage"]=="Purchase") else x,
#       5     'genre' : lambda x: [','.join(x)]})
#       8 df2["nb_games_played"] = df["NameClean"].apply(lambda x : len(x))
#
# File ~/opt/anaconda3/envs/MJ2MachineLearning/lib/python3.9/site-packages/pandas/core/series.py:958, in Series.__getitem__(self, key)
#     957 elif key_is_scalar:
# --> 958     return self._get_value(key)
#     960 if is_hashable(key):
#     961     # Otherwise index.get_value will raise InvalidIndexError
#
# File ~/opt/anaconda3/envs/MJ2MachineLearning/lib/python3.9/site-packages/pandas/core/series.py:1069, in Series._get_value(self, label, takeable)
#    1068 # Similar to Index.get_value, but we do not fall back to positional
# -> 1069 loc = self.index.get_loc(label)
#    1070 return self.index._get_values_for_loc(self, loc, label)
#
# File ~/opt/anaconda3/envs/MJ2MachineLearning/lib/python3.9/site-packages/pandas/core/indexes/base.py:3631, in Index.get_loc(self, key, method, tolerance)
#    3630 except KeyError as err:
# -> 3631     raise KeyError(key) from err
#    3632 except TypeError:
#    3633     # If we have a listlike key, _check_indexing_error will raise
#    3634     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3635     #  the TypeError.
#
# KeyError: 'Usage'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/envs/MJ2MachineLearning/lib/python3.9/site-packages/pandas/core/indexes/base.py:3629, in Index.get_loc(self, key, method, tolerance)
#    3628 try:
# -> 3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
#
# File ~/opt/anaconda3/envs/MJ2MachineLearning/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/opt/anaconda3/envs/MJ2MachineLearning/lib/python3.9/site-packages/pandas/_libs/index.pyx:144, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index_class_helper.pxi:41, in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'Usage'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [71], in <cell line: 3>()
#       1 df["genre"] = df["genre"].apply(lambda x:str(x).split(sep=",")[0]).replace("nan","other")
# ----> 3 df2 = df.groupby("Id_user").agg({
#       4     'NameClean' : lambda x: [','.join(x)]if(x["Usage"]=="Purchase") else x,
#       5     'genre' : lambda x: [','.join(x)]})
#       8 df2["nb_games_played"] = df["NameClean"].apply(lambda x : len(x))
#       9 df2.head()
#
# File ~/opt/anaconda3/envs/MJ2MachineLearning/lib/python3.9/site-packages/pandas/core/groupby/generic.py:869, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     866 func = maybe_mangle_lambdas(func)
#     868 op = GroupByApply(self, func, args, kwargs)
# --> 869 result = op.agg()
#     870 if not is_dict_like(func) and result is not None:
#     871     return result
#
# File ~/opt/anaconda3/envs/MJ2MachineLearning/lib/python3.9/site-packages/pandas/core/apply.py:168, in Apply.agg(self)
#     165     return self.apply_str()
#     167 if is_dict_like(arg):
# --> 168     return self.agg_dict_like()
#     169 elif is_list_like(arg):
#     170     # we require a list, but not a 'str'
#     171     return self.agg_list_like()
#
# File ~/opt/anaconda3/envs/MJ2MachineLearning/lib/python3.9/site-packages/pandas/core/apply.py:481, in Apply.agg_dict_like(self)
#     478     results = {key: colg.agg(how) for key, how in arg.items()}
#     479 else:
#     480     # key used for column selection and output
# --> 481     results = {
#     482         key: obj._gotitem(key, ndim=1).agg(how) for key, how in arg.items()
#     483     }
#     485 # set the final keys
#     486 keys = list(arg.keys())
#
# File ~/opt/anaconda3/envs/MJ2MachineLearning/lib/python3.9/site-packages/pandas/core/apply.py:482, in <dictcomp>(.0)
#     478     results = {key: colg.agg(how) for key, how in arg.items()}
#     479 else:
#     480     # key used for column selection and output
#     481     results = {
# --> 482         key: obj._gotitem(key, ndim=1).agg(how) for key, how in arg.items()
#     483     }
#     485 # set the final keys
#     486 keys = list(arg.keys())
#
# File ~/opt/anaconda3/envs/MJ2MachineLearning/lib/python3.9/site-packages/pandas/core/groupby/generic.py:291, in SeriesGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     287     return self._python_agg_general(func, *args, **kwargs)
#     288 except KeyError:
#     289     # TODO: KeyError is raised in _python_agg_general,
#     290     #  see test_groupby.test_basic
# --> 291     result = self._aggregate_named(func, *args, **kwargs)
#     293     # result is a dict whose keys are the elements of result_index
#     294     index = self.grouper.result_index
#
# File ~/opt/anaconda3/envs/MJ2MachineLearning/lib/python3.9/site-packages/pandas/core/groupby/generic.py:415, in SeriesGroupBy._aggregate_named(self, func, *args, **kwargs)
#     412 for name, group in self:
#     413     object.__setattr__(group, "name", name)
# --> 415     output = func(group, *args, **kwargs)
#     416     output = libreduction.extract_result(output)
#     417     if not initialized:
#     418         # We only do this validation on the first iteration
#
# Input In [71], in <lambda>(x)
#       1 df["genre"] = df["genre"].apply(lambda x:str(x).split(sep=",")[0]).replace("nan","other")
#       3 df2 = df.groupby("Id_user").agg({
# ----> 4     'NameClean' : lambda x: [','.join(x)]if(x["Usage"]=="Purchase") else x,
#       5     'genre' : lambda x: [','.join(x)]})
#       8 df2["nb_games_played"] = df["NameClean"].apply(lambda x : len(x))
#       9 df2.head()
#
# File ~/opt/anaconda3/envs/MJ2MachineLearning/lib/python3.9/site-packages/pandas/core/series.py:958, in Series.__getitem__(self, key)
#     955     return self._values[key]
#     957 elif key_is_scalar:
# --> 958     return self._get_value(key)
#     960 if is_hashable(key):
#     961     # Otherwise index.get_value will raise InvalidIndexError
#     962     try:
#     963         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~/opt/anaconda3/envs/MJ2MachineLearning/lib/python3.9/site-packages/pandas/core/series.py:1069, in Series._get_value(self, label, takeable)
#    1066     return self._values[label]
#    1068 # Similar to Index.get_value, but we do not fall back to positional
# -> 1069 loc = self.index.get_loc(label)
#    1070 return self.index._get_values_for_loc(self, loc, label)
#
# File ~/opt/anaconda3/envs/MJ2MachineLearning/lib/python3.9/site-packages/pandas/core/indexes/base.py:3631, in Index.get_loc(self, key, method, tolerance)
#    3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
# -> 3631     raise KeyError(key) from err
#    3632 except TypeError:
#    3633     # If we have a listlike key, _check_indexing_error will raise
#    3634     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3635     #  the TypeError.
#    3636     self._check_indexing_error(key)
#
# KeyError: 'Usage'

# %%
df2["FavoriteGenre"] = df2["genre"].apply(lambda x : mode(mode(x).split(sep=",")))
df2["FavoriteGenre"].head()
# Out:
# Id_user
# 5250      Action
# 76767     Action
# 86540      other
# 103360    Action
# 144736    Action
# Name: FavoriteGenre, dtype: object

# %%
mode(mode(df2["genre"][103360]).split(sep=","))
# Out:
# 'Action'

# %%
df2
# Out:
#                                                    NameClean  \
# Id_user
# 5250       [citiesskylines,citiesskylines,deusexhumanrevo...
# 76767      [counterstrike,counterstrike,callofdutyworldat...
# 86540      [theelderscrollsvskyrim,theelderscrollsvskyrim...
# 103360     [counterstrike,counterstrikeconditionzero,coun...
# 144736     [counterstrike,counterstrike,dayofdefeat,death...
# ...                                                      ...
# 309554670                    [mitosisthegame,mitosisthegame]
# 309626088  [ageofempiresiihdedition,ageofempiresiihdedition]
# 309812026              [counterstrikenexonzombies,robocraft]
# 309824202                                      [dota2,dota2]
# 309903146                                      [dota2,dota2]
#
#                                                        genre  nb_games_played  \
# Id_user
# 5250       [Simulation,Simulation,other,other,Action,Acti...             19.0
# 76767      [Action,Action,Action,Action,Strategy,Strategy...             11.0
# 86540      [RPG,RPG,Indie,Indie,Strategy,Strategy,Action,...             13.0
# 103360     [Action,other,other,Action,Action,Action,Actio...             25.0
# 144736     [Action,Action,Action,Action,Action,Action,Act...             23.0
# ...                                                      ...              ...
# 309554670                        [Free to Play,Free to Play]              NaN
# 309626088                                      [other,other]              NaN
# 309812026                                    [Action,Action]              NaN
# 309824202                                    [Action,Action]              NaN
# 309903146                                    [Action,Action]              NaN
#
#           FavoriteGenre
# Id_user
# 5250             Action
# 76767            Action
# 86540             other
# 103360           Action
# 144736           Action
# ...                 ...
# 309554670  Free to Play
# 309626088         other
# 309812026        Action
# 309824202        Action
# 309903146        Action
#
# [12393 rows x 4 columns]

# %%
df
# Out:
#           Id_user                        Name     Usage  TimePlayed  \
# 0       151603712  The Elder Scrolls V Skyrim  purchase         1.0
# 1       151603712  The Elder Scrolls V Skyrim      play       273.0
# 2       151603712                   Fallout 4  purchase         1.0
# 3       151603712                   Fallout 4      play        87.0
# 4       151603712                       Spore  purchase         1.0
# ...           ...                         ...       ...         ...
# 199995  128470551                 Titan Souls      play         1.5
# 199996  128470551  Grand Theft Auto Vice City  purchase         1.0
# 199997  128470551  Grand Theft Auto Vice City      play         1.5
# 199998  128470551                        RUSH  purchase         1.0
# 199999  128470551                        RUSH      play         1.4
#
#                      NameClean  \
# 0       theelderscrollsvskyrim
# 1       theelderscrollsvskyrim
# 2                     fallout4
# 3                     fallout4
# 4                        spore
# ...                        ...
# 199995              titansouls
# 199996  grandtheftautovicecity
# 199997  grandtheftautovicecity
# 199998                    rush
# 199999                    rush
#
#                                               all_reviews  \
# 0       Very Positive,(14,443),- 83% of the 14,443 use...
# 1       Very Positive,(14,443),- 83% of the 14,443 use...
# 2       Mostly Positive,(90,387),- 70% of the 90,387 u...
# 3       Mostly Positive,(90,387),- 70% of the 90,387 u...
# 4       Very Positive,(15,680),- 87% of the 15,680 use...
# ...                                                   ...
# 199995  Very Positive,(3,459),- 80% of the 3,459 user ...
# 199996  Very Positive,(8,542),- 91% of the 8,542 user ...
# 199997  Very Positive,(8,542),- 91% of the 8,542 user ...
# 199998  Very Positive,(69),- 85% of the 69 user review...
# 199999  Very Positive,(69),- 85% of the 69 user review...
#
#                     developer  \
# 0       Bethesda Game Studios
# 1       Bethesda Game Studios
# 2       Bethesda Game Studios
# 3       Bethesda Game Studios
# 4                      Maxis™
# ...                       ...
# 199995             Acid Nerve
# 199996         Rockstar Games
# 199997         Rockstar Games
# 199998        The Binary Mill
# 199999        The Binary Mill
#
#                                              popular_tags  \
# 0       Open World,RPG,Adventure,Singleplayer,Fantasy,...
# 1       Open World,RPG,Adventure,Singleplayer,Fantasy,...
# 2       Open World,Post-apocalyptic,Exploration,Single...
# 3       Open World,Post-apocalyptic,Exploration,Single...
# 4       Simulation,Sandbox,Open World,Exploration,Spac...
# ...                                                   ...
# 199995  Pixel Graphics,Difficult,Indie,Adventure,Actio...
# 199996  Open World,Action,1980s,Classic,Great Soundtra...
# 199997  Open World,Action,1980s,Classic,Great Soundtra...
# 199998                 Action,Sports,Racing,Simulation,VR
# 199999                 Action,Sports,Racing,Simulation,VR
#
#                                              game_details       genre  \
# 0       Single-player,Steam Achievements,Partial Contr...         RPG
# 1       Single-player,Steam Achievements,Partial Contr...         RPG
# 2       Single-player,Steam Achievements,Full controll...         RPG
# 3       Single-player,Steam Achievements,Full controll...         RPG
# 4                                           Single-player  Simulation
# ...                                                   ...         ...
# 199995  Single-player,Steam Achievements,Full controll...      Action
# 199996           Single-player,Partial Controller Support      Action
# 199997           Single-player,Partial Controller Support      Action
# 199998  Single-player,Multi-player,Online Multi-Player...      Action
# 199999  Single-player,Multi-player,Online Multi-Player...      Action
#
#                                          game_description  \
# 0        About This Game Winner of more than 200 Game ...
# 1        About This Game Winner of more than 200 Game ...
# 2        About This Game Bethesda Game Studios, the aw...
# 3        About This Game Bethesda Game Studios, the aw...
# 4        About This Game  From Single Cell to Galactic...
# ...                                                   ...
# 199995   About This Game Between our world and the wor...
# 199996   About This Game Welcome to Vice City. Welcome...
# 199997   About This Game Welcome to Vice City. Welcome...
# 199998   About This Game  Are you ready for the ultima...
# 199999   About This Game  Are you ready for the ultima...
#
#                                            mature_content _merge
# 0        Mature Content Description  The developers de...   both
# 1        Mature Content Description  The developers de...   both
# 2                                                     NaN   both
# 3                                                     NaN   both
# 4                                                     NaN   both
# ...                                                   ...    ...
# 199995                                                NaN   both
# 199996                                                NaN   both
# 199997                                                NaN   both
# 199998                                                NaN   both
# 199999                                                NaN   both
#
# [200000 rows x 13 columns]
